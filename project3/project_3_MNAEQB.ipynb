# %% [markdown]
# ## Welcome to Numerical Methods Applied to Chemical and Biological Engineering ([MNAEQB](https://guia.unl.pt/en/2022/fct/program/1062/course/12563)) Course @NOVA-FCT
#
# ###MINI-PROJECT III
#
# ####Contacts:
# If you have any questions regarding the exercises or any feedback, feel free to contact R. Costa, rs.costa (at) fct.unl.pt or R. Oliveira rmo (at) fct.unl.pt
#
# ---
# ---
#
# NOTES:
#
# - We will be using Python ([Google Colaboratory](https://colab.research.google.com/) or install [Jupyter](https://docs.anaconda.com/anaconda/install/index.html));
#
# - Save/run this notebook on your own laptop;
#
# - These exercises are designed to be run on a personal computer;
#
# - Save this notebook on your own laptop;
#
# - Each pratical exercise is followed by a code cell with some tips where you can type/execute your code; the **output results** are given at the *show hidden output* "button".

# %% [markdown]
# -----
# ###**PROBLEM 3 – Diffusion-Reaction Problem in a Immobilized Catalyst**
# -----
#
# ### Consider a porous spherical particle with a radius `R` = 0.008 m containing an immobilized catalyst that facilitates the reaction `X → 2Y` in an aqueous phase (see Figure). The concentrations of reactant `X` (`CsX`) and product `Y` (`CsX`) at the particle surface are equal to their bulk concentrations (`CbX` = 2000 mol/m3, `CbY` = 0 mol/m3), and the process is in steady-state. The effective diffusivity (`De`) of X and Y in water is 7.1e-9 m2/s and 2.3e-8, respectively.
# ### The process inside the sphere follows a first order intrinsic kinetics `𝑣X = - k1.CX` and `𝑣Y = 2.k1.CX`, with `k1` = 8.4e-3 s-1:
#
# ![Fig2.png](data:image/png;base64,...)

# %% [markdown]
# ###**Problem 3.1**
# -----
#
# ####*a)* Compute and plot the intraparticle concentration profiles of `X` (`CX(r)`) and `Y` (`CY(r)`) over `r`.
# ####*b)* Plot the intrinsic reaction rates, `𝑣X(𝑟)` and `𝑣Y(𝑟)`.

# %%
###TYPE YOUR CODE HERE (...)




#imports


#define a function to return intrinsic vX and vY



#define ODE function (use intraparticle material balances)



#define boundary condition function



#define size of spheres domain



#define initial guess



#solve BVP problem



#plots
# Out:
# The maximum number of mesh nodes is exceeded.

# %% [markdown]
# ###**Problem 3.2**
# -----
#
# ### Consider a steady-state continuous reactor containing immobilized catalyst in porous spherical particles with radius `R` (see previous problem 3.1). The reactor volume (`V` = 8 m3) is a perfectly mixed suspension of these particles and the aqueous solution, with *Nernst* diffusion coefficients  `𝑘X` = 1.8e-5 𝑚/𝑠 and `𝑘Y` = 3.1e-5 𝑚/𝑠 . No reaction occur in the bulk and the macroporosity is `𝑒` = 0,78 (𝑣/𝑣).
#
#
# ![Fig3.png](data:image/png;base64,...)
#
#
# ####*a)* Compute and plot the intraparticle concentration profiles of `X` (`CX(r)`) and `Y` (`CY(r)`) over `r`.
#
# ####*b)* Compute the production of `Y` in mol/year assuming full year operation.

# %%
###TYPE YOUR CODE HERE (...)




#imports



#define a function to return intrinsic CA and CY



#define ODE function (use intraparticle material balances)



#define objective function (use macroscopic material balances and solve_ivp)



#use "minimize" function to find the root of the system of equations



#plots
# Out:
#            message: `gtol` termination condition is satisfied.
#            success: True
#             status: 1
#                fun: 7.638676565037687e-15
#                  x: [ 1.085e+00  9.762e+03]
#                nit: 37
#               nfev: 84
#               njev: 28
#               nhev: 0
#           cg_niter: 40
#       cg_stop_cond: 4
#               grad: [ 4.710e-08  5.260e-12]
#    lagrangian_grad: [-4.848e-11  1.543e-14]
#             constr: [array([ 1.085e+00,  9.762e+03])]
#                jac: [<2x2 sparse matrix of type '<class 'numpy.float64'>'
#                     	with 2 stored elements in Compressed Sparse Row format>]
#        constr_nfev: [0]
#        constr_njev: [0]
#        constr_nhev: [0]
#                  v: [array([-4.715e-08, -5.245e-12])]
#             method: tr_interior_point
#         optimality: 4.848149706477388e-11
#   constr_violation: 0.0
#     execution_time: 1.7747619152069092
#          tr_radius: 149553848.2983857
# ...
