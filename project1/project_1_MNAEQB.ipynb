# %% [markdown]
# ## Welcome to Numerical Methods Applied to Chemical and Biological Engineering ([MNAEQB](https://guia.unl.pt/en/2022/fct/program/1062/course/12563)) Course @NOVA-FCT
#
# ###MINI-PROJECT I
#
# ####Contacts:
# If you have any questions regarding the exercises or any feedback, feel free to contact R. Costa, rs.costa (at) fct.unl.pt or R. Oliveira
#
# ---
# ---
#
# NOTES:
#
# - We will be using Python ([Google Colaboratory](https://colab.research.google.com/) or install [Jupyter](https://docs.anaconda.com/anaconda/install/index.html));
#
# - Save/run this notebook on your own laptop;
#
# - These exercises are designed to be run on a personal computer;
#
# - Save this notebook on your own laptop;
#
# - Each pratical exercise is followed by a code cell with some tips where you can type/execute your code; the **output results** are given at the *show hidden output* "button".

# %% [markdown]
# -----
# ###**PROBLEM 1 – Bioreactor Simulation & Optimization**
# -----
#
#
# ###Consider the Park&Ramirez fed-batch bioreactor model [[1]](https://doi.org/10.1002/aic.690340917) with a *Saccharomyces cerevisiae* SEY2102 strain expressing the heterologous protein SUC2-s2.
# ###**What's the best operation mode (batch, fed-batch or continuous) that maximizes the protein SUC2-s2 productivity?**
# ####The model comprises 5 state variables: `𝑃𝑀` - concentration of secreted SUC2-s2 [g/L]; `𝑃𝑇` - concentration of total SUC2-s2 [g/L]; `𝑋` biomass concentration [g/L]; `𝑆` - glucose concentration [g/L] and `𝑉` −culture volume [L]. The growth kinetics are unstructured with 3 rate equations: `𝛷` − SUC2-s2 secretion rate [h-1]; `𝑓𝑃` − SUC2-s2 expression rate [g g-1 h-1] and `𝜇` − specific growth rate [h-1].
# ####The material balances, kinetic rates, initial conditions and other constants of the model are listed in **Table 1** and **Table 2**.

# %% [markdown]
# ![Table1_ex1.png](data:image/png;base64,...)
#
# ![Table2_ex1.png](data:image/png;base64,...)
#
# ###**Problem 1.1**
# -----
#
# ####*a)* Simulate the *Park&Ramirez* bioreactor for **batch operation** and plot the concentrations/volume over time during 15 h.
# ####*b)* Determine the optimal initial concentration of substrate (`S0`) that maximizes the absolute productivity of the secreted protein in batch culture and plot the concentrations/volume for the optimal `S0`. Assume process duration of 15 h.
#
# **NOTE**: `Table 1` specifies the material balance equations for the semi-continuous operation. Adapt the equations for the batch operation.

# %%
###TYPE YOUR CODE HERE (...)



## PROBLEM 1.1 a) and b)
#imports


#--------------------------------------------------------
#define function for state variables

#unpacking state variables (function arguments)

#kinetic rates


#process control


#macroscopic material balances


#return derivatives

#-----------------------------------------------
#define function to simulate the model using S0 as argument


#define time spans and initial states vector


#integration using solve_ivp



#----------------------------------------------------
#define objective function ((Pmfinal*Vfinal)/tfinal) that computes absolute productivity in g/h



#----------------------------------------------------
#plot the simulation results before optimization for S0 = 5 g/L



#----------------------------------------------------
#optimize the bioreactor and obtain optimal S0 that maximizes the protein productivity using "minimize" function



#----------------------------------------------------
#plot the simulatation results after optimization for optimal S0
# Out:
# <ipython-input-2-02b97785089b>:69: OptimizeWarning: Unknown solver options: verbose
#   res=minimize(profitfun,x0=1,bounds=[(0,2)], options={'disp':True,'verbose':3})
# /usr/local/lib/python3.10/dist-packages/scipy/integrate/_ivp/base.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   y0 = np.asarray(y0)
#   message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#   success: True
#    status: 0
#       fun: -0.9723310422797892
#         x: [ 6.120e-01]
#       nit: 5
#       jac: [ 3.220e-06]
#      nfev: 18
#      njev: 9
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#
#
# optimal S0 = 0.6120 g/l
# maximum productivity = 0.9723 g/h

# %% [markdown]
# ###**Problem 1.2**
# -----
#
# ####*a)* Simulate the Park&Ramirez bioreactor in **semi-continuous** operation during 15 hours. Assume `F` = 0.1 L/h = constant and plot the concentrations/volume over time.
# ####*b)* Determine the optimal feed profile `F(t)`, that maximizes the productivity.

# %%
###TYPE YOUR CODE HERE (...)



## PROBLEM 1.2 a)
#imports



#-----------------------------------------------
#define function for state variables

  #unpacking state variables (function arguments)

  #kinetic rates


  #process control


  #macroscopic material balances



  #return derivatives


#-----------------------------------------------
#define time spans and initial states vector


# integration using solve_ivp



#-----------------------------------------------
#plot the simulatation results for F=0.1 L/h

# %%
###TYPE YOUR CODE HERE (...)



## PROBLEM 1.2 b)
#imports


#--------------------------------------------------------
#define function for state variables using Fin as argument

  #state variables

  #kinetic rates

  #process control

  #macroscopic material balances


#-----------------------------------------------
#define function to simulate the model usinf solve_ivp

  #define time spans and X vector


  #integration


#-----------------------------------------------
#define objective function ((Pmfinal*Vfinal(tf))/tfinal) that computes absolute productivity in g/h


#-----------------------------------------------
#optimize the feed profile, F(t) to maximizes the protein productivity using "minimize" function


#-----------------------------------------------
#plot the simulation results after optimization
# Out:
# <ipython-input-2-d00198f60785>:62: OptimizeWarning: Unknown solver options: verbose
#   res=minimize(profitfun,x0=0,bounds=[(0,2)],method='SLSQP', options={'disp':True,'verbose':3})
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1.8685905350990053
#             Iterations: 5
#             Function evaluations: 15
#             Gradient evaluations: 5
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -1.8685905350990053
#        x: [ 5.664e-02]
#      nit: 5
#      jac: [ 6.198e-03]
#     nfev: 15
#     njev: 5
#
#
# optimal Fin = 0.05664 l/h
# maximum productivity = 1.86859 g/h
# <ipython-input-2-d00198f60785>:66: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('\n\noptimal Fin = %.5f l/h'% (Fin))

# %% [markdown]
# ###**Problem 1.3**
# -----
#
# ####*a)* Determine the optimal Feed rate (`Fin`) , that maximizes the absolute productivity in a continuous bioreactor at steady state (i.e., for `t` = 150 h).
# ####*b)* Simulate the *Park&Ramirez* bioreactor for continuous bioreactor operation at the optimal `Fin` during 150h.
#
# NOTE: `Table 1` specifies the material balance equations for the semi-continuous operation. Modify the equations for the transiente operation.

# %%
###TYPE YOUR CODE HERE (...)



## PROBLEM 1.3 a) and 1.3 b)

#imports


#--------------------------------------------------------
#define function for state variables using Fin as argument

  #state variables


  #kinetic rates


  #process control


  #macroscopic material balances


#-----------------------------------------------
#define function to simulate the model usinf solve_ivp

  #define time spans and initial states vector

  #integration


#-----------------------------------------------
#define objective function ((Pmfinal*Fin) that computes absolute productivity in g/h


#-----------------------------------------------
#optimize the feed rate (Fin) to maximizes the protein productivity


#-----------------------------------------------
#plot the simulation results for the optimal feed rate (Fin)
# Out:
# <ipython-input-1-d04106cdd364>:55: OptimizeWarning: Unknown solver options: verbose
#   res = minimize(profitfun,x0=0.6,bounds=[(0,1)],method='SLSQP', options={'disp':True,'verbose':3})
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -82.88829870019761
#             Iterations: 4
#             Function evaluations: 9
#             Gradient evaluations: 4
#
#
#  Results:
#   Fin = 0.68829 L/h
#   maximum productivity = 82.88830 g-PM/h
# <ipython-input-1-d04106cdd364>:60: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('  Fin = %.5f L/h'%(Fin))
