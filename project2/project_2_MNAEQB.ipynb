# %% [markdown]
# ## Welcome to Numerical Methods Applied to Chemical and Biological Engineering ([MNAEQB](https://guia.unl.pt/en/2022/fct/program/1062/course/12563)) Course @NOVA-FCT
#
# ###MINI-PROJECT II
#
# ####Contacts:
# If you have any questions regarding the exercises or any feedback, feel free to contact R. Costa, rs.costa (at) fct.unl.pt or R. Oliveira rmo (at) fct.unl.pt
#
# ---
# ---
#
# NOTES:
#
# - We will be using Python ([Google Colaboratory](https://colab.research.google.com/) or install [Jupyter](https://docs.anaconda.com/anaconda/install/index.html));
#
# - Save/run this notebook on your own laptop;
#
# - These exercises are designed to be run on a personal computer;
#
# - Save this notebook on your own laptop;
#
# - Each pratical exercise is followed by a code cell with some tips where you can type/execute your code; the **output results** are given at the *show hidden output* "button".

# %% [markdown]
# -----
# ###**PROBLEM 2 – Plotting and Regression Analysis of Bioprocess Data**
# -----
#
# ###A microorganism was cultivated in a 15 L continuous bioreactor for 900 h with concentration `X` [g/L] and grows on glucose, `S` [g/L] (20 g/L in the inlet stream, `So`) to produced a bioproduct, `P` [g/L]. The bioreactor was subject to step changes in the feeding rate, `F` [L/h] but the volume is constant (`V` = 8 L over the process duration). The samples were taken every 25 h in triplicate (see *bioprocess_data.csv*).

# %% [markdown]
# ###**Problem 2.1**
# -----
#
# ####*a)* Represent a boxplot of mean measured concentrations `X`, `S` and `P`.
#
# ####*b)* Plot `X`, `S` and `P` over time including respective 95% confidence intervals at each time point.

# %%
###TYPE YOUR CODE HERE (...)



#imports



#read dataset



#compute mean, std and confidence intervals



#time series plots for X, S and P with errorbars



#boxplot
# Out:
# <Axes: xlabel='Time[h]', ylabel='Pmean[g/L]'>

# %% [markdown]
# ###**Problem 2.2**
# -----
# ####*a)* Estimate the time point mean of `𝝁` (specific growth rate [h-1]), `𝒗𝑺` (specific glucose consumption [g/gh]) and `𝒗𝑷` (specific production rate [g/gh]) from the experimental measurements (`X`, `S` and `P`) and plot `𝜇`, `𝑣𝑆`, and `𝑣𝑃` over time.
#
# ####*b)* Represent a boxplot of `𝝁`, `𝒗𝑺` and `𝒗𝑷` .

# %%
###TYPE YOUR CODE HERE (...)



#imports



#transform dataframe to arrays



#estimate kinetic rates until len(X)



#add to dataframe



#scatter plot



#boxplot

# %% [markdown]
# ###**Problem 2.3**
# -----
#
# ####Consider the ODE model (1)-(4) to describe the bioprocess with *a prior* high level of confidence. However, the kinetic parameters (`𝜇_𝑚𝑎𝑥, 𝐾_𝑆, 𝑌_(𝑆/𝑋), 𝛼 , 𝛽`) of the kinetic rate equations are unknown:
#
# ![Fig1.png](data:image/png;base64,...)
#
# ####*a)* Estimates the unknown kinetic parameters, `𝜃={𝜇_𝑚𝑎𝑥, 𝐾_𝑆, 𝑌_(𝑆/𝑋),𝛼, 𝛽}` including the 95% confidence intervals by least squares regression of the rate data, `Ydata={𝜇, 𝑣_𝑆, 𝑣_𝑃}` against concentration data `Xdata={𝑋,𝑆,𝑃}`.
#
# ####*b)* Plot the model predictions *versus* experimental data of `𝜇`, `𝑣_𝑆` and `𝑣_𝑃` over time.

# %%
###TYPE YOUR CODE HERE (...)



#imports



#define function for the model outputs (mu_cal, vs_cal, vp_cal)



#define function to return model residuals



#use least_squares function to return solution



#parameter confidence intervals



#print parameter sresults withi ci 95%



#plot model predictions versus experimental data of 𝜇, 𝑣_𝑆 and 𝑣_𝑃 over time
# Out:
# 1a) Output:
#
# 𝜇_max= 0.2254110629855923 +/- 0.005343954217531229
# K_S=    3.818848608860399 +/- 0.10144010766222762
# Y_XS=   1.610824604295984 +/- 0.007915500299338905
# 𝛼=  0.29499096506322453 +/- 0.0069551605702101406
# 𝛽=  0.008986488487702775 +/- 8.140994591892855e-05
#
#
#
#
# 1b) Output:
# <ipython-input-25-292a063c5c98>:42: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(t[0:-1],mu,'bo',t[0:-1],mucalc,'b-', marker="s")
# <ipython-input-25-292a063c5c98>:46: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ro" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(t[0:-1],vs,'ro',t[0:-1],vscalc,'r-', marker="D")
# Text(0, 0.5, 'v_P (g/g.h)')
